# %%
#! python2
# -*- coding: utf-8 -*-
import pprint
import pymongo
import datetime
import numpy as np
from pymongo import MongoClient

from scipy import spatial

import pylab

import os

import progressbar

db_name = 'twitter'
col_name = 'cluster_score'

# %%
from sklearn import metrics
from sklearn.cluster import DBSCAN
# from sklearn.datasets.samples_generator import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation, NMF
from sklearn.metrics.pairwise import cosine_similarity

from igraph import *
import igraph
import math
from operator import itemgetter

# %%
class MyPrettyPrinter(pprint.PrettyPrinter):
    def format(self, object, context, maxlevels, level):
        if isinstance(object, unicode):
            return (object.encode('thai'), True, False)
        return pprint.PrettyPrinter.format(self, object, context, maxlevels, level)

def go_print( input ):
    MyPrettyPrinter().pprint(input)
    # ppp = pprint.PrettyPrinter(indent=4)
    # ppp.pprint(input)
    return;

def get_midnight(time):
    return time.replace(minute=0, hour=0, second=0, microsecond=0)

def get_time_gap(time,hour_gap=1,min_gap=1):
    h = time.hour
    m = time.minute
    o_h = h/hour_gap*hour_gap
    o_m = m/min_gap*min_gap
    return time.replace(hour=o_h, minute=o_m, second=0, microsecond=0)

def get_week_year(time):
    return tuple([time.isocalendar()[0], time.isocalendar()[1]])

def get_thai_midnight(time):
    out = time + datetime.timedelta(hours=7)
    out = out.replace(minute=0, hour=0, second=0, microsecond=0) - datetime.timedelta(hours=7)
    return out

# %%
if __name__ == '__main__':
    client = MongoClient()
    db = client[db_name]

    result = db[col_name].create_index([('ts', pymongo.ASCENDING)])
    cursor = db[col_name].find({})

    bar = progressbar.ProgressBar(maxval=cursor.count()+1, widgets=[progressbar.Bar('#', '[', ']'), ' ', progressbar.Percentage()])
    bar.start()
    data=1
    all_score = {}
    d_all_score = {}
    for doc in cursor:
        data += 1
        bar.update(data)
        description = doc['description']
        levels = doc['levels']
        score_type = doc['type']
        
        completeness_score = doc['completeness_score']
        homogeneity_score = doc['homogeneity_score']
        v_measure_score = doc['v_measure_score']

        if not all_score.has_key(description):
            all_score[description] = {}
            d_all_score[description] = {}
            d_all_score[description]['completeness_score'] = []
            d_all_score[description]['homogeneity_score'] = []
            d_all_score[description]['v_measure_score'] = []
        
        if not all_score[description].has_key(levels):
            all_score[description][levels] = {}
            
        if not all_score[description][levels].has_key(score_type):
            all_score[description][levels][score_type] = {}
            all_score[description][levels][score_type]['completeness_score'] = []
            all_score[description][levels][score_type]['homogeneity_score'] = []
            all_score[description][levels][score_type]['v_measure_score'] = []

            
        all_score[description][levels][score_type]['completeness_score'].append(completeness_score)
        all_score[description][levels][score_type]['homogeneity_score'].append(homogeneity_score)
        all_score[description][levels][score_type]['v_measure_score'].append(v_measure_score)
        
        d_all_score[description]['completeness_score'].append(completeness_score)
        d_all_score[description]['homogeneity_score'].append(homogeneity_score)
        d_all_score[description]['v_measure_score'].append(v_measure_score)
        
          
    bar.finish()
# Out:
# [########################################################################] 100%

# %%
for description,v1 in all_score.items():
    for levels,v2 in v1.items():
        for score_type,v3 in v2.items():
            for score_name, score_list in v3.items():
                print description,levels,score_type,score_name, 1.0*sum(score_list)/len(score_list)
            print ''
# Out:
# Markov Cluster topic 1 homogeneity_score 0.57315848347
# Markov Cluster topic 1 v_measure_score 0.623857972603
# Markov Cluster topic 1 completeness_score 0.71294360959
#
# Markov Cluster topic 4 homogeneity_score 0.57315848347
# Markov Cluster topic 4 v_measure_score 0.623857972603
# Markov Cluster topic 4 completeness_score 0.71294360959
#
# Markov Cluster topic_labels_re_noise 1 homogeneity_score 0.563119503603
# Markov Cluster topic_labels_re_noise 1 v_measure_score 0.264593918597
# Markov Cluster topic_labels_re_noise 1 completeness_score 0.194624123059
#
# Markov Cluster topic_labels_re_noise 4 homogeneity_score 0.563119503603
# Markov Cluster topic_labels_re_noise 4 v_measure_score 0.264593918597
# Markov Cluster topic_labels_re_noise 4 completeness_score 0.194624123059
#
# Markov Cluster minor_class 1 homogeneity_score 0.823464366757
# Markov Cluster minor_class 1 v_measure_score 0.762833188805
# Markov Cluster minor_class 1 completeness_score 0.718236573513
#
# Markov Cluster minor_class 4 homogeneity_score 0.823464366757
# Markov Cluster minor_class 4 v_measure_score 0.762833188805
# Markov Cluster minor_class 4 completeness_score 0.718236573513
#
# Markov Cluster major_class 1 homogeneity_score 0.816338263685
# Markov Cluster major_class 1 v_measure_score 0.409067015518
# Markov Cluster major_class 1 completeness_score 0.282198230495
#
# Markov Cluster major_class 4 homogeneity_score 0.816338263685
# Markov Cluster major_class 4 v_measure_score 0.409067015518
# Markov Cluster major_class 4 completeness_score 0.282198230495
#
# Affinity Propagation topic 1 homogeneity_score 0.526844109351
# Affinity Propagation topic 1 v_measure_score 0.58328954189
# Affinity Propagation topic 1 completeness_score 0.682529088309
#
# Affinity Propagation topic 4 homogeneity_score 0.526844109351
# Affinity Propagation topic 4 v_measure_score 0.58328954189
# Affinity Propagation topic 4 completeness_score 0.682529088309
#
# Affinity Propagation topic_labels_re_noise 1 homogeneity_score 0.609795464603
# Affinity Propagation topic_labels_re_noise 1 v_measure_score 0.296867876083
# Affinity Propagation topic_labels_re_noise 1 completeness_score 0.215705004719
#
# Affinity Propagation topic_labels_re_noise 4 homogeneity_score 0.609795464603
# Affinity Propagation topic_labels_re_noise 4 v_measure_score 0.296867876083
# Affinity Propagation topic_labels_re_noise 4 completeness_score 0.215705004719
#
# Affinity Propagation minor_class 1 homogeneity_score 0.667188584534
# Affinity Propagation minor_class 1 v_measure_score 0.629825522131
# Affinity Propagation minor_class 1 completeness_score 0.60997786785
#
# Affinity Propagation minor_class 4 homogeneity_score 0.667188584534
# Affinity Propagation minor_class 4 v_measure_score 0.629825522131
# Affinity Propagation minor_class 4 completeness_score 0.60997786785
#
# Affinity Propagation major_class 1 homogeneity_score 0.637849105412
# Affinity Propagation major_class 1 v_measure_score 0.329741416989
# Affinity Propagation major_class 1 completeness_score 0.230073764979
#
# Affinity Propagation major_class 4 homogeneity_score 0.637849105412
# Affinity Propagation major_class 4 v_measure_score 0.329741416989
# Affinity Propagation major_class 4 completeness_score 0.230073764979
#
# DBSCAN topic 1 homogeneity_score 0.33584004432
# DBSCAN topic 1 v_measure_score 0.438113865201
# DBSCAN topic 1 completeness_score 0.666459965639
#
# DBSCAN topic 4 homogeneity_score 0.507048345981
# DBSCAN topic 4 v_measure_score 0.580826971831
# DBSCAN topic 4 completeness_score 0.714225678847
#
# DBSCAN topic_labels_re_noise 1 homogeneity_score 0.400492575065
# DBSCAN topic_labels_re_noise 1 v_measure_score 0.236803303954
# DBSCAN topic_labels_re_noise 1 completeness_score 0.205552465287
#
# DBSCAN topic_labels_re_noise 4 homogeneity_score 0.592915254025
# DBSCAN topic_labels_re_noise 4 v_measure_score 0.390312924872
# DBSCAN topic_labels_re_noise 4 completeness_score 0.343534591718
#
# DBSCAN minor_class 1 homogeneity_score 0.445460776301
# DBSCAN minor_class 1 v_measure_score 0.503808293278
# DBSCAN minor_class 1 completeness_score 0.603447961109
#
# DBSCAN minor_class 4 homogeneity_score 0.764213103533
# DBSCAN minor_class 4 v_measure_score 0.754337586185
# DBSCAN minor_class 4 completeness_score 0.760102677043
#
# DBSCAN major_class 1 homogeneity_score 0.43886505908
# DBSCAN major_class 1 v_measure_score 0.298225241012
# DBSCAN major_class 1 completeness_score 0.235337053065
#
# DBSCAN major_class 4 homogeneity_score 0.752193749931
# DBSCAN major_class 4 v_measure_score 0.412428729808
# DBSCAN major_class 4 completeness_score 0.30318949663
#
# Filter Affinity Propagation topic 1 homogeneity_score 0.459416352612
# Filter Affinity Propagation topic 1 v_measure_score 0.533000430352
# Filter Affinity Propagation topic 1 completeness_score 0.666707127427
#
# Filter Affinity Propagation topic 4 homogeneity_score 0.460495503874
# Filter Affinity Propagation topic 4 v_measure_score 0.533212040273
# Filter Affinity Propagation topic 4 completeness_score 0.668535980816
#
# Filter Affinity Propagation topic_labels_re_noise 1 homogeneity_score 0.520418901559
# Filter Affinity Propagation topic_labels_re_noise 1 v_measure_score 0.268423560098
# Filter Affinity Propagation topic_labels_re_noise 1 completeness_score 0.202206414819
#
# Filter Affinity Propagation topic_labels_re_noise 4 homogeneity_score 0.572585707656
# Filter Affinity Propagation topic_labels_re_noise 4 v_measure_score 0.310767639675
# Filter Affinity Propagation topic_labels_re_noise 4 completeness_score 0.238426865533
#
# Filter Affinity Propagation minor_class 1 homogeneity_score 0.587987915939
# Filter Affinity Propagation minor_class 1 v_measure_score 0.585522351997
# Filter Affinity Propagation minor_class 1 completeness_score 0.598147531243
#
# Filter Affinity Propagation minor_class 4 homogeneity_score 0.621502808374
# Filter Affinity Propagation minor_class 4 v_measure_score 0.62175531493
# Filter Affinity Propagation minor_class 4 completeness_score 0.644475732203
#
# Filter Affinity Propagation major_class 1 homogeneity_score 0.548691648716
# Filter Affinity Propagation major_class 1 v_measure_score 0.304840297876
# Filter Affinity Propagation major_class 1 completeness_score 0.219234531896
#
# Filter Affinity Propagation major_class 4 homogeneity_score 0.591685829311
# Filter Affinity Propagation major_class 4 v_measure_score 0.331207030918
# Filter Affinity Propagation major_class 4 completeness_score 0.240863648654
#
# Filter Markov Cluster topic 1 homogeneity_score 0.487560692547
# Filter Markov Cluster topic 1 v_measure_score 0.568931604526
# Filter Markov Cluster topic 1 completeness_score 0.709358072656
#
# Filter Markov Cluster topic 4 homogeneity_score 0.498732253369
# Filter Markov Cluster topic 4 v_measure_score 0.581952013634
# Filter Markov Cluster topic 4 completeness_score 0.732138827232
#
# Filter Markov Cluster topic_labels_re_noise 1 homogeneity_score 0.499630433532
# Filter Markov Cluster topic_labels_re_noise 1 v_measure_score 0.257303521925
# Filter Markov Cluster topic_labels_re_noise 1 completeness_score 0.197372166086
#
# Filter Markov Cluster topic_labels_re_noise 4 homogeneity_score 0.540029223006
# Filter Markov Cluster topic_labels_re_noise 4 v_measure_score 0.297313349615
# Filter Markov Cluster topic_labels_re_noise 4 completeness_score 0.237318705013
#
# Filter Markov Cluster minor_class 1 homogeneity_score 0.708501033216
# Filter Markov Cluster minor_class 1 v_measure_score 0.712878604123
# Filter Markov Cluster minor_class 1 completeness_score 0.720743095395
#
# Filter Markov Cluster minor_class 4 homogeneity_score 0.793212926869
# Filter Markov Cluster minor_class 4 v_measure_score 0.795733065843
# Filter Markov Cluster minor_class 4 completeness_score 0.804183356274
#
# Filter Markov Cluster major_class 1 homogeneity_score 0.686253797806
# Filter Markov Cluster major_class 1 v_measure_score 0.387770708986
# Filter Markov Cluster major_class 1 completeness_score 0.278772246724
#
# Filter Markov Cluster major_class 4 homogeneity_score 0.791070102163
# Filter Markov Cluster major_class 4 v_measure_score 0.436500029789
# Filter Markov Cluster major_class 4 completeness_score 0.319259392246

# %%
for description,v1 in d_all_score.items():
    for score_name, score_list in v1.items():
        print description,score_name, 1.0*sum(score_list)/len(score_list)
    print ''
# Out:
# Markov Cluster homogeneity_score 0.694020154379
# Markov Cluster v_measure_score 0.515088023881
# Markov Cluster completeness_score 0.477000634164
#
# Affinity Propagation homogeneity_score 0.610419315975
# Affinity Propagation v_measure_score 0.459931089273
# Affinity Propagation completeness_score 0.434571431464
#
# DBSCAN homogeneity_score 0.529628613529
# DBSCAN v_measure_score 0.451857114518
# DBSCAN completeness_score 0.478981236167
#
# Filter Affinity Propagation homogeneity_score 0.545348083505
# Filter Affinity Propagation v_measure_score 0.436091083265
# Filter Affinity Propagation completeness_score 0.434824729074
#
# Filter Markov Cluster homogeneity_score 0.625623807814
# Filter Markov Cluster v_measure_score 0.504797862305
# Filter Markov Cluster completeness_score 0.499893232703
