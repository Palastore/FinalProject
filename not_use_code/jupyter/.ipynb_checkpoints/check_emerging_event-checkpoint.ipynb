# %%
#! python2
# -*- coding: utf-8 -*-
import pprint
import pymongo
import datetime
import numpy as np
from pymongo import MongoClient

from scipy import spatial

import pylab

import os

import progressbar

db_name = 'twitter'
predict_col_name = 'event_list'
true_col_name = 'after_process_replab'

event_size = 15

# %%
from sklearn import metrics
from sklearn.cluster import DBSCAN
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation, NMF
from sklearn.metrics.pairwise import cosine_similarity

from igraph import *
import igraph
import math
from operator import itemgetter

# %%
def get_sim(doc_a,doc_b):
    return 1 - spatial.distance.cosine(doc_a, doc_b)

# %%
def get_midnight(time):
    return time.replace(minute=0, hour=0, second=0, microsecond=0)

# %%
if __name__ == '__main__':
    client = MongoClient()
    db = client[db_name]

    result = db[predict_col_name].create_index([('ts', pymongo.ASCENDING)])
    cursor = db[predict_col_name].find({})

    bar = progressbar.ProgressBar(maxval=cursor.count()+1, widgets=[progressbar.Bar('#', '[', ']'), ' ', progressbar.Percentage()])
    bar.start()
    data=1
    predict_event = {}
    predict_event_id = {}
    alltime = []
    for doc in cursor:
        data += 1
        bar.update(data)
        
        date = doc['time']
        description = doc['description']
        group_id = doc['group_id']
        if group_id > 0:
            true_name = doc['true_name']
            tweet_id =doc['tweet_id']
            size = doc['size']
            past = doc['past']

#             print size,past
            if not predict_event.has_key(date):
                predict_event[date] = {}
                predict_event_id[date] = {}
            if not predict_event[date].has_key(description):
                predict_event[date][description] = []
                predict_event_id[date][description] = []
            if size >= event_size and len(past) == 0:
                predict_event[date][description].append(true_name)
                predict_event_id[date][description].extend(tweet_id)
        
        alltime.append(date)
    
    alltime = set(alltime)
        
    bar.finish()
# Out:
# [########################################################################] 100%

# %%
if __name__ == '__main__':
    client = MongoClient()
    db = client[db_name]

    result = db[true_col_name].create_index([('ts', pymongo.ASCENDING)])
    cursor = db[true_col_name].find({'ts':{'$gte':1338508800}}).sort([('ts', pymongo.ASCENDING)])
    
    all_event = {}
    all_event_id = {}
    true_event_id_2 = {}

    bar = progressbar.ProgressBar(maxval=cursor.count()+1, widgets=[progressbar.Bar('#', '[', ']'), ' ', progressbar.Percentage()])
    bar.start()
    data=1
    for doc in cursor:
        data += 1
        bar.update(data)
        
        ts = doc['ts']
        entity_id = doc['entity_id']
        topic = doc['topic']
        tweet_id = doc['tweet_id']
        topic_dense = doc['topic_dense']
        datetime_object = datetime.datetime.fromtimestamp(ts)
        time_gap = get_midnight(datetime_object)
        
        if not all_event.has_key(time_gap):
            all_event[time_gap] = []
            all_event_id[time_gap] = {}
            true_event_id_2[time_gap] = []
        true_event_id_2[time_gap].append(tweet_id)
#         if tweet_id =='208604422492786688':
#             print 'in',time_gap
        if topic_dense == 1:
#         if True:
            if not (topic in all_event[time_gap]):
                 all_event[time_gap].append(topic)
            if not (all_event_id[time_gap].has_key(topic)):
                all_event_id[time_gap][topic] = []
            all_event_id[time_gap][topic].append(tweet_id)

        
    bar.finish()
#     print len(date)
# Out:
# [########################################################################] 100%

# %%
starttime = datetime.datetime(2012, 6, 1)
usetime = []
true_event = {}
true_event_id = {}


for day in sorted(alltime):
    if day >= starttime:
        usetime.append(day)
        true_event[day] = []
        true_event_id[day] = []

for now_time, event_list in all_event.items():
    old_time = now_time - datetime.timedelta(days=1)
    for event in event_list:
        if all_event.has_key(old_time):
            if not (event in all_event[old_time]):
                if  true_event.has_key(now_time):
                    true_event[now_time].append(event)
                    true_event_id[now_time].extend( all_event_id[now_time][event] )
        else:
            if  true_event.has_key(now_time):
                true_event[now_time].append(event)
                true_event_id[now_time].extend( all_event_id[now_time][event] )

# %%
# Recall = How many relevantitems are selected?
# Precision = How many selecteditems are relevant?
def cal_recall_precision(true, predict):
    recall, precision = 0,0
    if len(true) == 0 and len(predict) == 0:
        recall = 1
        precision = 1
    elif len(true) == 0:
        recall = 0
        precision = 0
    elif len(predict) == 0:
        recall = 0
        precision = 1
    else:
        r = 0
        p = 0
        for x in true:
            if x in predict:
                r += 1
        recall = 1.0*r/len(true)

        for x in predict:
            if x in true:
                p += 1

        precision = 1.0*p/len(predict)
    
    return recall,precision

# %%
all_score = {}
all_score_id = {}
bar = progressbar.ProgressBar(maxval=len(usetime)+1, widgets=[progressbar.Bar('#', '[', ']'), ' ', progressbar.Percentage()])
bar.start()
data=1
for day in usetime:
    data += 1
    bar.update(data)
    for description,d_event in predict_event[day].items():
        if not all_score.has_key(description):
            all_score[description] = {}
            all_score[description]['recall'] = []
            all_score[description]['precision'] = []
            
            all_score_id[description] = {}
            all_score_id[description]['recall'] = []
            all_score_id[description]['precision'] = []
        recall, precision = cal_recall_precision(true_event[day], d_event)
        all_score[description]['recall'].append(recall)
        all_score[description]['precision'].append(precision)
#         print true_event[day]
#         print d_event

#         print '\n\n'
        
        recall, precision = cal_recall_precision(true_event_id[day], predict_event_id[day][description])
        all_score_id[description]['recall'].append(recall)
        all_score_id[description]['precision'].append(precision)
#         print description
#         print len(true_event_id[day])
#         print len(predict_event_id[day][description])
#         print ''
bar.finish()
# Out:
# [########################################################################] 100%

# %%
for description,score_data in all_score.items():
    for score_key,score in score_data.items():
        print description, score_key, sum(score)/len(score)
    print ''
# Out:
# Affinity Propagation recall 0.332974190276
# Affinity Propagation precision 0.336004368349
#
# DBSCAN recall 0.643948906262
# DBSCAN precision 0.811596778015
#
# Markov Cluster recall 0.503245681711
# Markov Cluster precision 0.515159908848

# %%
# remove noise topic('')
# >=10 and no past using true_name
# Affinity Propagation recall 0.29092060088
# Affinity Propagation precision 0.258155993447

# DBSCAN recall 0.463127769353
# DBSCAN precision 0.672125483693

# Markov Cluster recall 0.371064243498
# Markov Cluster precision 0.375932078098



# >=15 and no past using true_name
# Affinity Propagation recall 0.332974190276
# Affinity Propagation precision 0.336004368349

# DBSCAN recall 0.643948906262
# DBSCAN precision 0.811596778015

# Markov Cluster recall 0.503245681711
# Markov Cluster precision 0.515159908848

# %%
# >=10 and no past using true_name
# Affinity Propagation recall 0.230328836817
# Affinity Propagation precision 0.21997646693

# DBSCAN recall 0.413198842559
# DBSCAN precision 0.568723841112

# Markov Cluster recall 0.353924558159
# Markov Cluster precision 0.308296225287



# >=15 and no past using true_name
# Affinity Propagation recall 0.279718864744
# Affinity Propagation precision 0.322364305979

# DBSCAN recall 0.59031825002
# DBSCAN precision 0.715233357024

# Markov Cluster recall 0.457319660537
# Markov Cluster precision 0.423584824142

# %%
for description,score_data in all_score_id.items():
    for score_key,score in score_data.items():
        print description, score_key, sum(score)/len(score)
#         print score
    print ''
# Out:
# Affinity Propagation recall 0.340671369697
# Affinity Propagation precision 0.333549833505
#
# DBSCAN recall 0.641642903856
# DBSCAN precision 0.804690509565
#
# Markov Cluster recall 0.520358917544
# Markov Cluster precision 0.505077553767

# %%
# remove noise topic('')
# >=10 and no past using tweet_id
# Affinity Propagation recall 0.287937947412
# Affinity Propagation precision 0.237605426436

# DBSCAN recall 0.449532057079
# DBSCAN precision 0.654753576815

# Markov Cluster recall 0.407875505471
# Markov Cluster precision 0.369869384098



# >=15 and no past using tweet_id
# Affinity Propagation recall 0.340671369697
# Affinity Propagation precision 0.333549833505

# DBSCAN recall 0.641642903856
# DBSCAN precision 0.804690509565

# Markov Cluster recall 0.520358917544
# Markov Cluster precision 0.505077553767

# %%
# >=10 and no past using tweet_id
# Affinity Propagation recall 0.245800261178
# Affinity Propagation precision 0.20547564428

# DBSCAN recall 0.406399695626
# DBSCAN precision 0.566916380388

# Markov Cluster recall 0.401920920727
# Markov Cluster precision 0.30475288307




# >=15 and no past using tweet_id
# Affinity Propagation recall 0.288697136985
# Affinity Propagation precision 0.315978275562

# DBSCAN recall 0.589171812469
# DBSCAN precision 0.713648269949

# Markov Cluster recall 0.474449714173
# Markov Cluster precision 0.414411697168

# %%
sorted(true_event.items())
# Out:
# [(datetime.datetime(2012, 6, 1, 0, 0),
#   [u'Glass door concussion',
#    u"England's League Cup sponsorship",
#    u'Haters',
#    u'Fan Craze',
#    u'other topics',
#    u'MDNA Tour Israel',
#    u'MISC Product Comments/Mentions',
#    u'Madonna - Lady Gaga Feud',
#    u'Fans go to the concerts']),
#  (datetime.datetime(2012, 6, 2, 0, 0),
#   [u'Product Comparison',
#    u'Mention of a product',
#    u'Fan Support',
#    u'Song/Lyrics Tweet',
#    u'Concerts & Tickets',
#    u'Comments about Coldplay',
#    u'Coldplay Fans',
#    u'Jokes',
#    u'Concert at the Emirates',
#    u'Comments about concerts',
#    u'Saving pop music']),
#  (datetime.datetime(2012, 6, 3, 0, 0),
#   [u'Song-Video: Princess of China',
#    u'For sale',
#    u' Show: The Voice UK final',
#    u'Madonna is the Only Queen of Pop Trend']),
#  (datetime.datetime(2012, 6, 4, 0, 0),
#   [u'Fan Comments', u'Performance on TV', u'Compliments']),
#  (datetime.datetime(2012, 6, 5, 0, 0),
#   [u'Product Endorsement', u'Jubilee Concert']),
#  (datetime.datetime(2012, 6, 6, 0, 0), []),
#  (datetime.datetime(2012, 6, 7, 0, 0), []),
#  (datetime.datetime(2012, 6, 8, 0, 0), []),
#  (datetime.datetime(2012, 6, 9, 0, 0), [u'Actress Lindsay Lohan Accident']),
#  (datetime.datetime(2012, 6, 10, 0, 0), [u'Band - Favourite']),
#  (datetime.datetime(2012, 6, 11, 0, 0), []),
#  (datetime.datetime(2012, 6, 12, 0, 0),
#   [u"(Song) I Don't Wanna Miss a Thing"]),
#  (datetime.datetime(2012, 6, 13, 0, 0), []),
#  (datetime.datetime(2012, 6, 14, 0, 0), [u'Capital One soccer cup']),
#  (datetime.datetime(2012, 6, 15, 0, 0), []),
#  (datetime.datetime(2012, 6, 16, 0, 0), [u'Le Mans Sponsorship ']),
#  (datetime.datetime(2012, 6, 17, 0, 0), [u'other topics']),
#  (datetime.datetime(2012, 6, 18, 0, 0), []),
#  (datetime.datetime(2012, 6, 19, 0, 0), []),
#  (datetime.datetime(2012, 6, 20, 0, 0), [u'other topics']),
#  (datetime.datetime(2012, 6, 21, 0, 0), []),
#  (datetime.datetime(2012, 6, 22, 0, 0), []),
#  (datetime.datetime(2012, 6, 23, 0, 0), []),
#  (datetime.datetime(2012, 6, 24, 0, 0), [u'other topics']),
#  (datetime.datetime(2012, 6, 25, 0, 0), []),
#  (datetime.datetime(2012, 6, 26, 0, 0), []),
#  (datetime.datetime(2012, 6, 27, 0, 0),
#   [u'LS media coverage', u'LIBOR Scandal (LS)']),
#  (datetime.datetime(2012, 6, 28, 0, 0),
#   [u'Call for more serious actions (LS)',
#    u'Bob Diamond in the LS',
#    u'other topics',
#    u'Important responses for Rate Manipulation',
#    u'Barclays and corruption in UK (LS)',
#    u'Critics to banks',
#    u'LS and the UK internal Politics',
#    u'LS effect on share prices']),
#  (datetime.datetime(2012, 6, 29, 0, 0), [u'New album: New Day']),
#  (datetime.datetime(2012, 6, 30, 0, 0), []),
#  (datetime.datetime(2012, 7, 1, 0, 0), []),
#  (datetime.datetime(2012, 7, 2, 0, 0), []),
#  (datetime.datetime(2012, 7, 3, 0, 0), []),
#  (datetime.datetime(2012, 7, 4, 0, 0), []),
#  (datetime.datetime(2012, 7, 5, 0, 0), []),
#  (datetime.datetime(2012, 7, 6, 0, 0), []),
#  (datetime.datetime(2012, 7, 7, 0, 0), []),
#  (datetime.datetime(2012, 7, 8, 0, 0), []),
#  (datetime.datetime(2012, 7, 9, 0, 0), []),
#  (datetime.datetime(2012, 7, 10, 0, 0), []),
#  (datetime.datetime(2012, 7, 11, 0, 0), []),
#  (datetime.datetime(2012, 7, 12, 0, 0), []),
#  (datetime.datetime(2012, 7, 13, 0, 0), []),
#  (datetime.datetime(2012, 7, 14, 0, 0), []),
#  (datetime.datetime(2012, 7, 15, 0, 0), []),
#  (datetime.datetime(2012, 7, 16, 0, 0), []),
#  (datetime.datetime(2012, 7, 17, 0, 0),
#   [u'money laundring/ David Bagley steps down']),
#  (datetime.datetime(2012, 7, 18, 0, 0), []),
#  (datetime.datetime(2012, 7, 19, 0, 0),
#   [u'Fine for deceptive marketing tactics']),
#  (datetime.datetime(2012, 7, 20, 0, 0), []),
#  (datetime.datetime(2012, 7, 21, 0, 0), []),
#  (datetime.datetime(2012, 7, 22, 0, 0), []),
#  (datetime.datetime(2012, 7, 23, 0, 0), []),
#  (datetime.datetime(2012, 7, 24, 0, 0), []),
#  (datetime.datetime(2012, 7, 25, 0, 0), []),
#  (datetime.datetime(2012, 7, 26, 0, 0), []),
#  (datetime.datetime(2012, 7, 27, 0, 0), [u'Super Junior vs PSY']),
#  (datetime.datetime(2012, 7, 28, 0, 0), []),
#  (datetime.datetime(2012, 7, 29, 0, 0), []),
#  (datetime.datetime(2012, 7, 30, 0, 0), []),
#  (datetime.datetime(2012, 7, 31, 0, 0), []),
#  (datetime.datetime(2012, 8, 1, 0, 0), []),
#  (datetime.datetime(2012, 8, 2, 0, 0), []),
#  (datetime.datetime(2012, 8, 3, 0, 0), []),
#  (datetime.datetime(2012, 8, 8, 0, 0), []),
#  (datetime.datetime(2012, 8, 10, 0, 0), []),
#  (datetime.datetime(2012, 8, 11, 0, 0), []),
#  (datetime.datetime(2012, 8, 12, 0, 0), []),
#  (datetime.datetime(2012, 8, 14, 0, 0), []),
#  (datetime.datetime(2012, 8, 15, 0, 0), [u'Capital One soccer cup']),
#  (datetime.datetime(2012, 8, 16, 0, 0), []),
#  (datetime.datetime(2012, 8, 21, 0, 0), []),
#  (datetime.datetime(2012, 8, 22, 0, 0), []),
#  (datetime.datetime(2012, 8, 24, 0, 0), []),
#  (datetime.datetime(2012, 8, 25, 0, 0), []),
#  (datetime.datetime(2012, 8, 26, 0, 0), []),
#  (datetime.datetime(2012, 8, 29, 0, 0), []),
#  (datetime.datetime(2012, 8, 30, 0, 0), []),
#  (datetime.datetime(2012, 8, 31, 0, 0), [u'Capital One soccer cup']),
#  (datetime.datetime(2012, 9, 1, 0, 0), []),
#  (datetime.datetime(2012, 9, 2, 0, 0), []),
#  (datetime.datetime(2012, 9, 3, 0, 0), []),
#  (datetime.datetime(2012, 9, 4, 0, 0), []),
#  (datetime.datetime(2012, 9, 5, 0, 0), []),
#  (datetime.datetime(2012, 9, 6, 0, 0), []),
#  (datetime.datetime(2012, 9, 7, 0, 0), []),
#  (datetime.datetime(2012, 9, 8, 0, 0), []),
#  (datetime.datetime(2012, 9, 9, 0, 0), []),
#  (datetime.datetime(2012, 9, 10, 0, 0), []),
#  (datetime.datetime(2012, 9, 11, 0, 0), [u'Ad - Vibrator (India)']),
#  (datetime.datetime(2012, 9, 12, 0, 0), []),
#  (datetime.datetime(2012, 9, 13, 0, 0), []),
#  (datetime.datetime(2012, 9, 14, 0, 0), []),
#  (datetime.datetime(2012, 9, 15, 0, 0), []),
#  (datetime.datetime(2012, 9, 16, 0, 0), []),
#  (datetime.datetime(2012, 9, 17, 0, 0), []),
#  (datetime.datetime(2012, 9, 18, 0, 0), []),
#  (datetime.datetime(2012, 9, 19, 0, 0), []),
#  (datetime.datetime(2012, 9, 20, 0, 0), []),
#  (datetime.datetime(2012, 9, 21, 0, 0), []),
#  (datetime.datetime(2012, 9, 22, 0, 0), []),
#  (datetime.datetime(2012, 9, 23, 0, 0), []),
#  (datetime.datetime(2012, 9, 24, 0, 0), []),
#  (datetime.datetime(2012, 9, 25, 0, 0), [u'Capital One soccer cup']),
#  (datetime.datetime(2012, 9, 26, 0, 0), []),
#  (datetime.datetime(2012, 9, 27, 0, 0), [u'Capital One Cup (soccer)']),
#  (datetime.datetime(2012, 9, 28, 0, 0),
#   [u'Class Action Lawsuit - Merrill Lynch']),
#  (datetime.datetime(2012, 9, 29, 0, 0), []),
#  (datetime.datetime(2012, 9, 30, 0, 0), []),
#  (datetime.datetime(2012, 10, 1, 0, 0), []),
#  (datetime.datetime(2012, 10, 2, 0, 0), []),
#  (datetime.datetime(2012, 10, 3, 0, 0), []),
#  (datetime.datetime(2012, 10, 4, 0, 0), []),
#  (datetime.datetime(2012, 10, 5, 0, 0), []),
#  (datetime.datetime(2012, 10, 6, 0, 0), []),
#  (datetime.datetime(2012, 10, 7, 0, 0), []),
#  (datetime.datetime(2012, 10, 8, 0, 0), []),
#  (datetime.datetime(2012, 10, 9, 0, 0), []),
#  (datetime.datetime(2012, 10, 10, 0, 0), []),
#  (datetime.datetime(2012, 10, 11, 0, 0), []),
#  (datetime.datetime(2012, 10, 12, 0, 0), []),
#  (datetime.datetime(2012, 10, 13, 0, 0),
#   [u'RBS\xb4s queries branch sale collapse']),
#  (datetime.datetime(2012, 10, 14, 0, 0), []),
#  (datetime.datetime(2012, 10, 15, 0, 0), []),
#  (datetime.datetime(2012, 10, 16, 0, 0), []),
#  (datetime.datetime(2012, 10, 17, 0, 0), []),
#  (datetime.datetime(2012, 10, 18, 0, 0), []),
#  (datetime.datetime(2012, 10, 19, 0, 0), []),
#  (datetime.datetime(2012, 10, 20, 0, 0), []),
#  (datetime.datetime(2012, 10, 21, 0, 0), []),
#  (datetime.datetime(2012, 10, 22, 0, 0), [u'other topics']),
#  (datetime.datetime(2012, 10, 23, 0, 0), []),
#  (datetime.datetime(2012, 10, 24, 0, 0),
#   [u'$1billion Lawsuit - Mortgage Fraud']),
#  (datetime.datetime(2012, 10, 25, 0, 0),
#   [u'Former director (Rajat Gupta) - Sentenced to two years']),
#  (datetime.datetime(2012, 10, 26, 0, 0), []),
#  (datetime.datetime(2012, 10, 27, 0, 0), []),
#  (datetime.datetime(2012, 10, 28, 0, 0), []),
#  (datetime.datetime(2012, 10, 29, 0, 0),
#   [u'Capital One Cup (soccer)',
#    u'Mitt Romney statements',
#    u'Chrysler response to Romney']),
#  (datetime.datetime(2012, 10, 30, 0, 0),
#   [u'GS building - Light',
#    u'NYU Hospital: backup power',
#    u'NYU Hospital: nurses/doctors help patients',
#    u'NYU Hospital: praying for the patients',
#    u'NYU Hospital: evacuations',
#    u'NYU Hospital: ambulances evacuating patients',
#    u'GS building light vs. Hospital',
#    u'Ironic comments: Goldman Sachs-NYU Hospital']),
#  (datetime.datetime(2012, 10, 31, 0, 0), []),
#  (datetime.datetime(2012, 11, 1, 0, 0),
#   [u'Loss of scientific research due to Sandy',
#    u'Scarce importance of Capital One Cup (soccer)']),
#  (datetime.datetime(2012, 11, 2, 0, 0),
#   [u'Chrysler response to Donald Tramp']),
#  (datetime.datetime(2012, 11, 3, 0, 0), []),
#  (datetime.datetime(2012, 11, 4, 0, 0), [u'HSBC  Champions']),
#  (datetime.datetime(2012, 11, 5, 0, 0),
#   [u'money laundering / terrorism finance']),
#  (datetime.datetime(2012, 11, 6, 0, 0),
#   [u'other topics',
#    u'Halts Car selling in US',
#    u'Day off for workers to vote on the national election']),
#  (datetime.datetime(2012, 11, 7, 0, 0), []),
#  (datetime.datetime(2012, 11, 8, 0, 0), []),
#  (datetime.datetime(2012, 11, 9, 0, 0),
#   [u'other topics',
#    u'Jersey criminal account holders',
#    u'corruption / tax evasion india']),
#  (datetime.datetime(2012, 11, 10, 0, 0), [u'Princeton Offense']),
#  (datetime.datetime(2012, 11, 11, 0, 0), []),
#  (datetime.datetime(2012, 11, 12, 0, 0), [u'Concerts and shows at BC']),
#  (datetime.datetime(2012, 11, 13, 0, 0), [u'other topics']),
#  (datetime.datetime(2012, 11, 14, 0, 0), []),
#  (datetime.datetime(2012, 11, 15, 0, 0), []),
#  (datetime.datetime(2012, 11, 16, 0, 0), []),
#  (datetime.datetime(2012, 11, 17, 0, 0), [u'other topics']),
#  (datetime.datetime(2012, 11, 18, 0, 0),
#   [u'(Harvard) Rivalry in Sports',
#    u'Jaguar Land Rover announce joint venture with Chery Automobile in China']),
#  (datetime.datetime(2012, 11, 19, 0, 0),
#   [u'AC/DC Finally Available on iTunes']),
#  (datetime.datetime(2012, 11, 20, 0, 0), [u'other topics']),
#  (datetime.datetime(2012, 11, 21, 0, 0), []),
#  (datetime.datetime(2012, 11, 22, 0, 0), []),
#  (datetime.datetime(2012, 11, 23, 0, 0), []),
#  (datetime.datetime(2012, 11, 24, 0, 0),
#   [u'Suzuki cup', u'other topics', u'Top 10 greatest voices']),
#  (datetime.datetime(2012, 11, 25, 0, 0),
#   [u'Sports - Football - Matches - Stanford vs. UCLA', u'Sports - Pac-12']),
#  (datetime.datetime(2012, 11, 26, 0, 0), []),
#  (datetime.datetime(2012, 11, 27, 0, 0), [u'Games at BC']),
#  (datetime.datetime(2012, 11, 28, 0, 0), [u'other topics', u'Suzuki cup']),
#  (datetime.datetime(2012, 11, 29, 0, 0), []),
#  (datetime.datetime(2012, 11, 30, 0, 0), [u'Suzuki cup']),
#  (datetime.datetime(2012, 12, 1, 0, 0), []),
#  (datetime.datetime(2012, 12, 2, 0, 0),
#   [u'other topics', u'Sports - Football - Matches - Stanford vs. Wisconsin']),
#  (datetime.datetime(2012, 12, 3, 0, 0), []),
#  (datetime.datetime(2012, 12, 4, 0, 0),
#   [u'Kennedy Center Honors 2012',
#    u'other topics',
#    u"Interview: Led Zeppelin on 'The Late Show with David Letterman'"]),
#  (datetime.datetime(2012, 12, 5, 0, 0), [u'Barclays center documentary']),
#  (datetime.datetime(2012, 12, 6, 0, 0), []),
#  (datetime.datetime(2012, 12, 7, 0, 0), [u'For sale']),
#  (datetime.datetime(2012, 12, 8, 0, 0), [u'Suzuki cup']),
#  (datetime.datetime(2012, 12, 9, 0, 0), []),
#  (datetime.datetime(2012, 12, 10, 0, 0), []),
#  (datetime.datetime(2012, 12, 11, 0, 0),
#   [u'Capital One Cup (soccer)', u'money laundering / terrorism finance']),
#  (datetime.datetime(2012, 12, 12, 0, 0),
#   [u'Vote M5 for Peoples Choice',
#    u'Games at BC',
#    u'Suzuki cup',
#    u'Spam',
#    u'Recalls of vehicles']),
#  (datetime.datetime(2012, 12, 13, 0, 0),
#   [u'Attractiveness of the Artist',
#    u'121212 Concert',
#    u'(12-12-12 Concert) Collection of Artist',
#    u'Bon Jovi and Springsteen',
#    u"Bon jovi's outfit in 121212",
#    u'Comments about BJ in the 121212',
#    u'Fans',
#    u'BJ and the age ',
#    u'(12-12-12 Concert) Alicia Keys Performance']),
#  (datetime.datetime(2012, 12, 14, 0, 0), []),
#  (datetime.datetime(2012, 12, 15, 0, 0),
#   [u'Launching Honda CB150R Street Fire']),
#  (datetime.datetime(2012, 12, 16, 0, 0), []),
#  (datetime.datetime(2012, 12, 17, 0, 0),
#   [u'VH1 Divas: Tribute to Whitney Houston']),
#  (datetime.datetime(2012, 12, 18, 0, 0), []),
#  (datetime.datetime(2012, 12, 19, 0, 0),
#   [u'Capital One Cup (soccer)', u'The Voice']),
#  (datetime.datetime(2012, 12, 20, 0, 0), []),
#  (datetime.datetime(2012, 12, 21, 0, 0),
#   [u'New Kind of Magnetism and new State of Matter Discovered',
#    u'4 Minutes Song',
#    u'Madonna Will Save the World Trend',
#    u'Record of views on YouTube']),
#  (datetime.datetime(2012, 12, 22, 0, 0),
#   [u'Suzuki cup', u'Second Hand Sales']),
#  (datetime.datetime(2012, 12, 23, 0, 0), []),
#  (datetime.datetime(2012, 12, 24, 0, 0), []),
#  (datetime.datetime(2012, 12, 25, 0, 0),
#   [u'mention of a product', u'Comments about Coldplay']),
#  (datetime.datetime(2012, 12, 26, 0, 0),
#   [u'Commercials - Blake Griffin - Comment',
#    u'Download 12 Days of Christmas']),
#  (datetime.datetime(2012, 12, 27, 0, 0),
#   [u'Britney Spears and his ex-Brother in Law  extramarital relations',
#    u'Documentary',
#    u'Put in a good mood',
#    u'Bands that put me in a good mood: Coldplay',
#    u'Rumours about Whitney being murdered',
#    u'Kennedy Center Honors 2012',
#    u'Recall settlement',
#    u'Ask Madonna On Twitter Trend']),
#  (datetime.datetime(2012, 12, 28, 0, 0),
#   [u'Song lyrics',
#    u'Britney Spears could be fired from the X Factor',
#    u'Song/Lyrics Tweet',
#    u'Nice comments from fans',
#    u'Comments about Coldplay',
#    u'mention of a product',
#    u'Coldplay on TV',
#    u"Pique's Prank - Fool's day"]),
#  (datetime.datetime(2012, 12, 29, 0, 0), [u'Song-Video']),
#  (datetime.datetime(2012, 12, 30, 0, 0),
#   [u'Song: Scream & shout',
#    u'Comments about Coldplay',
#    u'Sports - Basketball (Women) - Matches - Stanford vs. Uconn',
#    u'Fan Craze - Beliebers',
#    u"PSY's birthday",
#    u'Sports - Basketball (Women) - Matches - Stanford vs. Uconn - Result',
#    u'Artist Quote Tweets']),
#  (datetime.datetime(2012, 12, 31, 0, 0),
#   [u'Concerts and Events',
#    u'Fan 2 Fan',
#    u'TT',
#    u'Song Mention',
#    u'Funny comments',
#    u'Product Comparison',
#    u'Anti Bieber',
#    u'Mental health booths',
#    u'Fan Defense',
#    u'Comments about concerts',
#    u'New Tattoo',
#    u'Adele and Taylor Swift',
#    u'Britney\xb4s next album',
#    u'Song Let me love you']),
#  (datetime.datetime(2013, 1, 1, 0, 0), [])]

# %%
num = 0
for e in true_event.values():
    num += len(e)
print 'num event :',num
print 'event per day :',1.0*num/len(true_event)
# Out:
# num event : 176
# event per day : 0.871287128713

# %%
# event_size = 10
# num event : 344
# event per day : 1.70297029703

# event_size = 15
# num event : 176
# event per day : 0.871287128713
