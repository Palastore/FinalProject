# %%
#! python2
# -*- coding: utf-8 -*-
import pprint
import pymongo
import datetime
import numpy as np
from pymongo import MongoClient

from scipy import spatial

import pylab

import os

import progressbar

db_name = 'twitter'
col_name = 'after_process'

# %%
from sklearn import metrics
from sklearn.cluster import DBSCAN
# from sklearn.datasets.samples_generator import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation, NMF
from sklearn.metrics.pairwise import cosine_similarity

from igraph import *
import igraph
import math
from operator import itemgetter

# %%
class MyPrettyPrinter(pprint.PrettyPrinter):
    def format(self, object, context, maxlevels, level):
        if isinstance(object, unicode):
            return (object.encode('thai'), True, False)
        return pprint.PrettyPrinter.format(self, object, context, maxlevels, level)

def go_print( input ):
    MyPrettyPrinter().pprint(input)
    # ppp = pprint.PrettyPrinter(indent=4)
    # ppp.pprint(input)
    return;

def get_midnight(time):
    return time.replace(minute=0, hour=0, second=0, microsecond=0)

def get_thai_midnight(time):
    out = time + datetime.timedelta(hours=7)
    out = out.replace(minute=0, hour=0, second=0, microsecond=0) - datetime.timedelta(hours=7)
    return out

# %%
if __name__ == '__main__':
    client = MongoClient()
    db = client[db_name]

    result = db[col_name].create_index([('ts', pymongo.ASCENDING)])
    cursor = db[col_name].find({ 'ts':{'$gte':1511654400000} }).sort([('ts', pymongo.ASCENDING)]).limit(40000)
    

    date = []
    text = []
    text_2 = []
    all_doc = []

    bar = progressbar.ProgressBar(maxval=cursor.count()+1, widgets=[progressbar.Bar('#', '[', ']'), ' ', progressbar.Percentage()])
    bar.start()
    data=1
    for doc in cursor:
        data += 1
        bar.update(data)
        
        ts = doc['ts']
        datetime_object = datetime.datetime.fromtimestamp(ts/1000)
        if True:
#         if len(doc['hashtags']) != 0:
            buf = doc['nouns']
            buf_2 = doc['nouns_nltk']
            for x in doc['hashtags']:
                if not x.lower() in buf:
                    buf.append(x.lower())
                if not x.lower() in buf_2:
                    buf_2.append(x.lower())
            all_doc.append(doc)
            date.append(datetime_object)
            text.append(' '.join(buf))
            text_2.append(' '.join(buf_2))
    bar.finish()
#     print len(date)
# Out:
# [########################################################################] 100%

# %%
def two_str(num):
    if num < 10:
        return str(0)+str(num)
    else:
        return str(num)

# %%
#time_gap <= 60
def split_time_gap(date,text,all_doc,time_gap):
    s_text = {}
    s_all_doc = {}
    for datetime_object in date:
        i = date.index(datetime_object)
        m = datetime_object.minute
        h = datetime_object.hour
        d = datetime_object.day
        key = two_str(d)+'/'+two_str(datetime_object.month)+'::'+two_str(h)+'.'+two_str((m/time_gap)*time_gap)
        if not s_text.has_key(key):
            s_text[key] = []
            s_all_doc[key] = []
        s_text[key].append(text[i])
        s_all_doc[key].append(all_doc[i])
    return s_text,s_all_doc
s_text,s_all_doc = split_time_gap(date,text,all_doc,60)

# %%
from math import *
import operator as op
import itertools

L = dict() # Lattice
Lkey = dict() # Key of each itemset
X = 0
N = 0

for c in range(100):
    L[c] = dict()
    Lkey[c] = dict()

# %%
#  n เลือก r ไม่สนลำดับ
def nCr(n, r):
    if n < r: return 0
    r = min(r, n-r)
    if r == 0: return 1
    numer = reduce(op.mul, range(n, n-r, -1))
    denom = reduce(op.mul, range(1, r+1))
    return numer//denom

# %%
def streamMining(stream, theta, epsilon):
    global L, Lkey
    for c in range(100):
        L[c] = dict()
        Lkey[c] = dict()
    X = 0
    N = 0
    print("Run streamMining")
    T = list() # Buffer
    f = 0 # Average 2-itemsets per transaction
    c = 0 # Number of call -> reducFreq
    for t in stream:
        T.append(t)
        update(t, 1)
        update(t, 2)
        f = twoItemsetPerTransaction(t)
        if len(L[2]) >= ceil(1/(theta*epsilon)) * f:
            reducFreq(2)
            c += 1
            i = 2
            while len(L[i]) != 0:
                i += 1
                for tp in T:
                    if len(tp) >= i:
                        update(tp, i)
                reducFreq(i)
            for ii in range(i,100):
                L[ii] = dict()
                Lkey[ii] = dict()
            T = list()
    for k,v in L.items():
        sorted_v = sorted(v.items(), key=operator.itemgetter(1), reverse=True)
        L[k] = sorted_v
    return L

# %%
def twoItemsetPerTransaction(t):
    global X, N
    f = 0
    N += 1
    X += nCr(len(t), 2)
    f = ceil(X/N)
    return f

# %%
def update(t, i):
    global L, Lkey
    itemsets = createItemsets(t, i)

    for s in itemsets:
        if len(set(s)) != i:
            continue
        if s in L[i]:
            L[i][s] += 1
        elif i <= 2:
            L[i][s] = 1
        elif i > 2:
            mini_itemsets = createItemsets(s, i-1)
            chk = True
            for mini in mini_itemsets:
                if mini not in L[i-1]:
                    chk = False
                    break
            if chk:
                L[i][s] = 1

# %%
def reducFreq(i):
    global L
    remove = list()
    for s in L[i]:
        L[i][s] -= 1
        if L[i][s] <= 0:
            remove.append(s)
    for r in remove:
        del L[i][r]

# %%
def createItemsets(t, i):
    return tuple(map( lambda w: tuple(sorted(w)), list(itertools.combinations(t, i)) ) )

# %%
output= {}
for k,v in s_text.items():
    sample = v
    sample_doc = s_all_doc[k]

    x = streamMining(map( lambda w: w.split(' '), sample ),0.01,0.01)
    
    output[k] = x.copy()
# Out:
# Run streamMining
# Run streamMining
# Run streamMining
# Run streamMining
# Run streamMining
# Run streamMining
# Run streamMining
# Run streamMining
# Run streamMining
# Run streamMining
# Run streamMining
# Run streamMining
# Run streamMining
# Run streamMining
# Run streamMining
# Run streamMining
# Run streamMining
# Run streamMining
# Run streamMining
# Run streamMining
# Run streamMining
# Run streamMining

# %%
#     output_text 
#     output_nouns 
#     out_nmf 
#     out_lda 
for k,v in sorted(output.items()):
    print '------' ,k, '-----'
    try:
        
        for data in v.values():
            remain = 15
            for top in data:
                print top
                remain -= 1
                if remain == 0:
                    break
    except :
        pass
# Out:
# ------ 26/11::07.00 -----
# (('',), 204)
# ((u'day',), 53)
# ((u'game',), 51)
# ((u'job',), 50)
# ((u'time',), 49)
# ((u'people',), 45)
# ((u'team',), 44)
# ((u'night',), 40)
# ((u'today',), 37)
# ((u'hiring',), 37)
# ((u'tonight',), 33)
# ((u'morning',), 32)
# ((u'thing',), 31)
# ((u'alabama',), 28)
# ((u'auburn',), 26)
# ((u'hiring', u'job'), 37)
# ((u'careerarc', u'job'), 20)
# ((u'careerarc', u'hiring'), 20)
# ((u'job', u'opening'), 16)
# ((u'hiring', u'opening'), 16)
# ((u'people', u'time'), 13)
# ((u'eagle', u'war'), 12)
# ((u'job', u'team'), 10)
# ((u'mph', u'wind'), 10)
# ((u'careerarc', u'opening'), 9)
# ((u'college', u'football'), 9)
# ((u'opening', u'team'), 9)
# ((u'hiring', u'team'), 9)
# ((u'spring', u'valley'), 8)
# ((u'spring', u'toll'), 8)
# ------ 26/11::08.00 -----
# (('',), 290)
# ((u'time',), 57)
# ((u'man',), 43)
# ((u'people',), 38)
# ((u'day',), 37)
# ((u'year',), 36)
# ((u'job',), 34)
# ((u'girl',), 30)
# ((u'game',), 28)
# ((u'amp',), 27)
# ((u'today',), 27)
# ((u'night',), 26)
# ((u'thing',), 25)
# ((u'christma',), 24)
# ((u'tonight',), 24)
# ((u'hiring', u'job'), 22)
# ((u'careerarc', u'hiring'), 16)
# ((u'careerarc', u'job'), 15)
# ((u'time', u'year'), 10)
# ((u'christma', u'year'), 9)
# ((u'christma', u'time'), 8)
# ((u'cloud', u'mph'), 8)
# ((u'ass', u'shit'), 7)
# ((u'mph', u'wind'), 7)
# ((u'forecast', u'nov'), 7)
# ((u'mph', u'temperature'), 7)
# ((u'forecast', u'tonight'), 7)
# ((u'nov', u'tonight'), 7)
# ((u'cloud', u'wind'), 6)
# ((u'temperature', u'wind'), 6)
# ------ 26/11::09.00 -----
# (('',), 224)
# ((u'time',), 65)
# ((u'day',), 39)
# ((u'people',), 34)
# ((u'life',), 34)
# ((u'tonight',), 33)
# ((u'game',), 33)
# ((u'thing',), 32)
# ((u'shit',), 32)
# ((u'today',), 32)
# ((u'year',), 31)
# ((u'amp',), 26)
# ((u'job',), 25)
# ((u'christma',), 22)
# ((u'man',), 22)
# ((u'art', u'gallery'), 12)
# ((u'hiring', u'job'), 12)
# ((u'humidity', u'wind'), 10)
# ((u'missuniverse', u'philippines'), 9)
# ((u'bitch', u'money'), 8)
# ((u'bestprice', u'woman'), 8)
# ((u'humidity', u'temperature'), 8)
# ((u'carol', u'christma'), 8)
# ((u'temperature', u'wind'), 8)
# ((u'job', u'opening'), 7)
# ((u'hiring', u'opening'), 7)
# ((u'art', u'scotia'), 6)
# ((u'pdx911', u'portland'), 6)
# ((u'barometer', u'temperature'), 5)
# ((u'today', u'wind'), 5)
# ------ 26/11::10.00 -----
# (('',), 277)
# ((u'day',), 52)
# ((u'time',), 49)
# ((u'people',), 41)
# ((u'game',), 35)
# ((u'today',), 34)
# ((u'life',), 30)
# ((u'man',), 29)
# ((u'shit',), 29)
# ((u'amp',), 28)
# ((u'love',), 26)
# ((u'tonight',), 25)
# ((u'year',), 24)
# ((u'night',), 23)
# ((u'thing',), 20)
# ((u'hiring', u'job'), 12)
# ((u'harassment', u'hotline'), 9)
# ((u'humidity', u'temperature'), 8)
# ((u'missuniverse', u'philippines'), 8)
# ((u'barometer', u'today'), 7)
# ((u'rain', u'wind'), 7)
# ((u'today', u'wind'), 7)
# ((u'temperature', u'wind'), 7)
# ((u'rain', u'temperature'), 7)
# ((u'temperature', u'today'), 7)
# ((u'humidity', u'wind'), 7)
# ((u'humidity', u'rain'), 7)
# ((u'people', u'time'), 7)
# ((u'humidity', u'today'), 7)
# ((u'barometer', u'wind'), 7)
# ------ 27/11::11.00 -----
# (('',), 240)
# ((u'game',), 40)
# ((u'shit',), 37)
# ((u'time',), 35)
# ((u'man',), 32)
# ((u'year',), 31)
# ((u'people',), 31)
# ((u'day',), 29)
# ((u'night',), 27)
# ((u'thing',), 25)
# ((u'steeler',), 22)
# ((u'life',), 22)
# ((u'baby',), 21)
# ((u'ass',), 20)
# ((u'week',), 20)
# ((u'cop', u'number'), 12)
# ((u'hiring', u'job'), 11)
# ((u'deuce', u'joker'), 8)
# ((u'captain', u'tom'), 8)
# ((u'man', u'woman'), 7)
# ((u'brett', u'drive'), 7)
# ((u'man', u'scenario'), 6)
# ((u'license', u'number'), 6)
# ((u'helmet', u'steeler'), 6)
# ((u'4thimpactforgda2018', u'philippine'), 6)
# ((u'car', u'cop'), 6)
# ((u'helmet', u'hundley'), 6)
# ((u'game', u'packer'), 6)
# ((u'car', u'number'), 6)
# ((u'gda2018', u'philippine'), 6)
# ------ 27/11::12.00 -----
# (('',), 283)
# ((u'time',), 46)
# ((u'day',), 45)
# ((u'shit',), 38)
# ((u'life',), 37)
# ((u'people',), 36)
# ((u'man',), 29)
# ((u'thing',), 29)
# ((u'amp',), 28)
# ((u'today',), 27)
# ((u'night',), 26)
# ((u'morning',), 26)
# ((u'friend',), 25)
# ((u'love',), 25)
# ((u'game',), 25)
# ((u'hiring', u'job'), 13)
# ((u'humidity', u'temperature'), 12)
# ((u'humidity', u'wind'), 11)
# ((u'kmh', u'wind'), 10)
# ((u'humidity', u'kmh'), 10)
# ((u'mph', u'wind'), 9)
# ((u'game', u'plan'), 9)
# ((u'temperature', u'wind'), 9)
# ((u'kmh', u'temperature'), 8)
# ((u'monday', u'morning'), 8)
# ((u'trend', u'trndnl'), 8)
# ((u'button', u'morning'), 7)
# ((u'click', u'monday'), 7)
# ((u'button', u'retweet'), 7)
# ((u'click', u'marc'), 7)
# ------ 27/11::13.00 -----
# (('',), 272)
# ((u'time',), 66)
# ((u'day',), 57)
# ((u'week',), 40)
# ((u'man',), 39)
# ((u'people',), 34)
# ((u'morning',), 31)
# ((u'life',), 30)
# ((u'amp',), 30)
# ((u'friend',), 27)
# ((u'shit',), 27)
# ((u'thing',), 26)
# ((u'tomorrow',), 26)
# ((u'love',), 25)
# ((u'year',), 24)
# ((u'kmh', u'wind'), 14)
# ((u'hiring', u'job'), 14)
# ((u'humidity', u'wind'), 13)
# ((u'humidity', u'kmh'), 12)
# ((u'kmh', u'sky'), 12)
# ((u'humidity', u'sky'), 11)
# ((u'sky', u'wind'), 10)
# ((u'pressure', u'weather'), 9)
# ((u'enlistment', u'news'), 8)
# ((u'cloud', u'kmh'), 8)
# ((u'humidity', u'weather'), 8)
# ((u'kmh', u'pressure'), 8)
# ((u'weather', u'wind'), 8)
# ((u'kmh', u'weather'), 8)
# ((u'humidity', u'pressure'), 8)
# ------ 27/11::14.00 -----
# (('',), 245)
# ((u'day',), 60)
# ((u'time',), 53)
# ((u'people',), 43)
# ((u'man',), 36)
# ((u'morning',), 33)
# ((u'life',), 32)
# ((u'today',), 31)
# ((u'thing',), 29)
# ((u'year',), 28)
# ((u'night',), 27)
# ((u'wind',), 26)
# ((u'amp',), 24)
# ((u'friend',), 24)
# ((u'shit',), 24)
# ((u'humidity', u'wind'), 21)
# ((u'rain', u'wind'), 17)
# ((u'mph', u'wind'), 14)
# ((u'hiring', u'job'), 14)
# ((u'humidity', u'temperature'), 13)
# ((u'temperature', u'wind'), 13)
# ((u'kmh', u'wind'), 13)
# ((u'humidity', u'rain'), 12)
# ((u'humidity', u'mph'), 12)
# ((u'today', u'wind'), 11)
# ((u'rain', u'today'), 11)
# ((u'mph', u'temperature'), 11)
# ((u'ass', u'heil'), 10)
# ((u'cloud', u'kmh'), 10)
# ((u'rain', u'temperature'), 10)
# ------ 27/11::15.00 -----
# (('',), 219)
# ((u'time',), 52)
# ((u'thing',), 50)
# ((u'day',), 46)
# ((u'today',), 46)
# ((u'humidity',), 34)
# ((u'amp',), 31)
# ((u'shit',), 30)
# ((u'morning',), 30)
# ((u'people',), 29)
# ((u'life',), 27)
# ((u'wind',), 27)
# ((u'man',), 27)
# ((u'job',), 27)
# ((u'temperature',), 27)
# ((u'humidity', u'temperature'), 27)
# ((u'humidity', u'wind'), 26)
# ((u'temperature', u'wind'), 19)
# ((u'felizlunes', u'ton'), 18)
# ((u'mph', u'wind'), 17)
# ((u'hiring', u'job'), 17)
# ((u'humidity', u'rain'), 15)
# ((u'mph', u'temperature'), 15)
# ((u'humidity', u'mph'), 15)
# ((u'rain', u'wind'), 14)
# ((u'rain', u'temperature'), 14)
# ((u'humidity', u'kmh'), 13)
# ((u'kmh', u'wind'), 13)
# ((u'rain', u'today'), 12)
# ((u'barometer', u'temperature'), 10)
# ------ 27/11::16.00 -----
# (('',), 196)
# ((u'day',), 63)
# ((u'time',), 55)
# ((u'today',), 54)
# ((u'people',), 39)
# ((u'morning',), 35)
# ((u'mph',), 34)
# ((u'amp',), 34)
# ((u'wind',), 32)
# ((u'job',), 31)
# ((u'life',), 30)
# ((u'work',), 29)
# ((u'humidity',), 28)
# ((u'night',), 26)
# ((u'year',), 24)
# ((u'mph', u'wind'), 28)
# ((u'humidity', u'wind'), 26)
# ((u'humidity', u'mph'), 22)
# ((u'hiring', u'job'), 22)
# ((u'dong', u'mostoles'), 18)
# ((u'dong', u'felizlunes'), 18)
# ((u'humidity', u'temperature'), 18)
# ((u'temperature', u'wind'), 18)
# ((u'mph', u'temperature'), 18)
# ((u'humidity', u'rain'), 15)
# ((u'rain', u'today'), 15)
# ((u'rain', u'wind'), 15)
# ((u'mph', u'rain'), 12)
# ((u'game', u'goal'), 12)
# ((u'rugby', u'tongan'), 12)
# ------ 27/11::17.00 -----
# (('',), 231)
# ((u'day',), 81)
# ((u'time',), 57)
# ((u'people',), 46)
# ((u'today',), 44)
# ((u'harry',), 39)
# ((u'week',), 35)
# ((u'prince',), 31)
# ((u'amp',), 30)
# ((u'morning',), 30)
# ((u'news',), 30)
# ((u'thing',), 30)
# ((u'year',), 29)
# ((u'humidity',), 28)
# ((u'wedding',), 27)
# ((u'harry', u'prince'), 30)
# ((u'humidity', u'wind'), 26)
# ((u'humidity', u'kmh'), 25)
# ((u'kmh', u'wind'), 25)
# ((u'humidity', u'temperature'), 23)
# ((u'temperature', u'wind'), 22)
# ((u'kmh', u'temperature'), 20)
# ((u'trend', u'trndnl'), 18)
# ((u'alert', u'trend'), 14)
# ((u'rain', u'wind'), 14)
# ((u'humidity', u'rain'), 14)
# ((u'cloud', u'kmh'), 13)
# ((u'rain', u'temperature'), 13)
# ((u'hiring', u'job'), 12)
# ((u'mph', u'wind'), 10)
# ------ 27/11::18.00 -----
# (('',), 240)
# ((u'day',), 84)
# ((u'morning',), 59)
# ((u'time',), 55)
# ((u'today',), 44)
# ((u'monday',), 39)
# ((u'amp',), 36)
# ((u'job',), 35)
# ((u'week',), 33)
# ((u'birthday',), 32)
# ((u'people',), 28)
# ((u'thing',), 24)
# ((u'love',), 24)
# ((u'life',), 22)
# ((u'year',), 21)
# ((u'humidity', u'wind'), 18)
# ((u'hiring', u'job'), 14)
# ((u'monday', u'morning'), 14)
# ((u'humidity', u'kmh'), 13)
# ((u'kmh', u'wind'), 13)
# ((u'harry', u'prince'), 12)
# ((u'humidity', u'weather'), 10)
# ((u'mph', u'wind'), 10)
# ((u'pressure', u'wind'), 10)
# ((u'weather', u'wind'), 10)
# ((u'pressure', u'weather'), 10)
# ((u'humidity', u'pressure'), 10)
# ((u'birthday', u'day'), 9)
# ((u'rain', u'wind'), 8)
# ((u'humidity', u'temperature'), 8)
# ------ 27/11::19.00 -----
# (('',), 234)
# ((u'day',), 71)
# ((u'today',), 53)
# ((u'time',), 48)
# ((u'morning',), 44)
# ((u'job',), 42)
# ((u'year',), 38)
# ((u'people',), 37)
# ((u'hiring',), 35)
# ((u'amp',), 34)
# ((u'monday',), 33)
# ((u'week',), 33)
# ((u'man',), 27)
# ((u'birthday',), 26)
# ((u'night',), 24)
# ((u'hiring', u'job'), 29)
# ((u'humidity', u'wind'), 18)
# ((u'mph', u'wind'), 12)
# ((u'careerarc', u'hiring'), 12)
# ((u'humidity', u'mph'), 12)
# ((u'job', u'opening'), 10)
# ((u'humidity', u'temperature'), 10)
# ((u'monday', u'morning'), 10)
# ((u'hiring', u'opening'), 10)
# ((u'humidity', u'weather'), 9)
# ((u'harry', u'prince'), 9)
# ((u'fit', u'job'), 9)
# ((u'temperature', u'wind'), 9)
# ((u'weather', u'wind'), 9)
# ((u'careerarc', u'job'), 9)
# ------ 27/11::20.00 -----
# (('',), 220)
# ((u'job',), 93)
# ((u'today',), 78)
# ((u'hiring',), 77)
# ((u'day',), 67)
# ((u'time',), 61)
# ((u'people',), 48)
# ((u'careerarc',), 47)
# ((u'amp',), 42)
# ((u'week',), 41)
# ((u'year',), 36)
# ((u'opening',), 35)
# ((u'work',), 34)
# ((u'morning',), 30)
# ((u'monday',), 29)
# ((u'hiring', u'job'), 67)
# ((u'careerarc', u'hiring'), 47)
# ((u'careerarc', u'job'), 45)
# ((u'job', u'opening'), 30)
# ((u'hiring', u'opening'), 27)
# ((u'hiring', u'jobs'), 21)
# ((u'job', u'jobs'), 21)
# ((u'nov', u'today'), 18)
# ((u'careerarc', u'jobs'), 18)
# ((u'nov', u'tonight'), 18)
# ((u'today', u'tonight'), 18)
# ((u'careerarc', u'opening'), 17)
# ((u'healthcare', u'job'), 15)
# ((u'healthcare', u'hiring'), 15)
# ((u'mon', u'nov'), 14)
# ------ 27/11::21.00 -----
# (('',), 204)
# ((u'job',), 132)
# ((u'hiring',), 109)
# ((u'day',), 78)
# ((u'careerarc',), 74)
# ((u'today',), 58)
# ((u'time',), 56)
# ((u'opening',), 49)
# ((u'work',), 42)
# ((u'amp',), 39)
# ((u'people',), 38)
# ((u'week',), 34)
# ((u'life',), 33)
# ((u'monday',), 32)
# ((u'year',), 31)
# ((u'hiring', u'job'), 100)
# ((u'careerarc', u'job'), 74)
# ((u'careerarc', u'hiring'), 71)
# ((u'job', u'opening'), 41)
# ((u'hiring', u'opening'), 38)
# ((u'careerarc', u'opening'), 21)
# ((u'fit', u'job'), 21)
# ((u'job', u'team'), 19)
# ((u'opening', u'team'), 19)
# ((u'hiring', u'team'), 19)
# ((u'hiring', u'jobs'), 18)
# ((u'job', u'jobs'), 18)
# ((u'careerarc', u'jobs'), 15)
# ((u'humidity', u'wind'), 15)
# ((u'mph', u'wind'), 14)
# ------ 27/11::22.00 -----
# (('',), 228)
# ((u'job',), 113)
# ((u'hiring',), 93)
# ((u'careerarc',), 70)
# ((u'day',), 65)
# ((u'today',), 61)
# ((u'time',), 47)
# ((u'night',), 36)
# ((u'monday',), 31)
# ((u'people',), 31)
# ((u'work',), 30)
# ((u'week',), 30)
# ((u'life',), 30)
# ((u'year',), 28)
# ((u'guy',), 27)
# ((u'hiring', u'job'), 83)
# ((u'careerarc', u'hiring'), 69)
# ((u'careerarc', u'job'), 69)
# ((u'fit', u'job'), 25)
# ((u'job', u'opening'), 19)
# ((u'hiring', u'opening'), 19)
# ((u'fit', u'hiring'), 17)
# ((u'careerarc', u'fit'), 14)
# ((u'careerarc', u'opening'), 14)
# ((u'day', u'today'), 13)
# ((u'humidity', u'wind'), 13)
# ((u'job', u'jobs'), 11)
# ((u'hiring', u'jobs'), 11)
# ((u'mph', u'wind'), 10)
# ((u'job', u'manager'), 10)
# ------ 27/11::23.00 -----
# (('',), 231)
# ((u'job',), 125)
# ((u'hiring',), 112)
# ((u'careerarc',), 64)
# ((u'day',), 61)
# ((u'time',), 57)
# ((u'today',), 55)
# ((u'people',), 51)
# ((u'opening',), 46)
# ((u'year',), 38)
# ((u'work',), 33)
# ((u'life',), 29)
# ((u'shit',), 28)
# ((u'team',), 27)
# ((u'monday',), 26)
# ((u'hiring', u'job'), 101)
# ((u'careerarc', u'hiring'), 64)
# ((u'careerarc', u'job'), 64)
# ((u'job', u'opening'), 46)
# ((u'hiring', u'opening'), 41)
# ((u'careerarc', u'opening'), 23)
# ((u'hiring', u'jobs'), 18)
# ((u'job', u'jobs'), 18)
# ((u'fit', u'job'), 17)
# ((u'job', u'team'), 16)
# ((u'careerarc', u'jobs'), 16)
# ((u'opening', u'team'), 16)
# ((u'job', u'retail'), 14)
# ((u'mph', u'wind'), 13)
# ((u'hiring', u'retail'), 13)
# ------ 28/11::00.00 -----
# (('',), 214)
# ((u'job',), 124)
# ((u'hiring',), 111)
# ((u'careerarc',), 69)
# ((u'day',), 57)
# ((u'today',), 57)
# ((u'time',), 47)
# ((u'shit',), 42)
# ((u'opening',), 40)
# ((u'amp',), 40)
# ((u'year',), 38)
# ((u'people',), 38)
# ((u'man',), 33)
# ((u'thing',), 30)
# ((u'work',), 29)
# ((u'hiring', u'job'), 94)
# ((u'careerarc', u'hiring'), 69)
# ((u'careerarc', u'job'), 68)
# ((u'job', u'opening'), 37)
# ((u'hiring', u'opening'), 35)
# ((u'hiring', u'jobs'), 23)
# ((u'job', u'jobs'), 23)
# ((u'careerarc', u'opening'), 21)
# ((u'careerarc', u'jobs'), 20)
# ((u'fit', u'job'), 15)
# ((u'job', u'team'), 14)
# ((u'hiring', u'retail'), 13)
# ((u'opening', u'team'), 13)
# ((u'job', u'retail'), 13)
# ((u'detail', u'hiring'), 13)
# ------ 28/11::01.00 -----
# (('',), 232)
# ((u'job',), 130)
# ((u'hiring',), 113)
# ((u'careerarc',), 78)
# ((u'today',), 64)
# ((u'day',), 48)
# ((u'time',), 39)
# ((u'people',), 38)
# ((u'work',), 36)
# ((u'year',), 34)
# ((u'amp',), 33)
# ((u'opening',), 32)
# ((u'friend',), 32)
# ((u'life',), 32)
# ((u'thing',), 31)
# ((u'hiring', u'job'), 103)
# ((u'careerarc', u'hiring'), 78)
# ((u'careerarc', u'job'), 78)
# ((u'job', u'opening'), 31)
# ((u'hiring', u'opening'), 30)
# ((u'hiring', u'jobs'), 26)
# ((u'job', u'jobs'), 26)
# ((u'fit', u'job'), 26)
# ((u'hiring', u'retail'), 20)
# ((u'job', u'retail'), 19)
# ((u'careerarc', u'jobs'), 19)
# ((u'fit', u'hiring'), 18)
# ((u'careerarc', u'opening'), 18)
# ((u'careerarc', u'retail'), 17)
# ((u'careerarc', u'fit'), 16)
# ------ 28/11::02.00 -----
# (('',), 268)
# ((u'job',), 120)
# ((u'hiring',), 97)
# ((u'careerarc',), 73)
# ((u'day',), 53)
# ((u'time',), 52)
# ((u'people',), 41)
# ((u'today',), 41)
# ((u'work',), 39)
# ((u'year',), 37)
# ((u'opening',), 34)
# ((u'amp',), 33)
# ((u'love',), 33)
# ((u'girl',), 31)
# ((u'life',), 31)
# ((u'hiring', u'job'), 93)
# ((u'careerarc', u'job'), 73)
# ((u'careerarc', u'hiring'), 72)
# ((u'job', u'opening'), 32)
# ((u'hiring', u'opening'), 29)
# ((u'hiring', u'jobs'), 26)
# ((u'job', u'jobs'), 26)
# ((u'fit', u'job'), 24)
# ((u'careerarc', u'jobs'), 22)
# ((u'careerarc', u'opening'), 18)
# ((u'careerarc', u'fit'), 17)
# ((u'fit', u'hiring'), 16)
# ((u'mph', u'wind'), 12)
# ((u'hiring', u'nursing'), 12)
# ((u'healthcare', u'job'), 12)
# ------ 28/11::03.00 -----
# (('',), 233)
# ((u'job',), 149)
# ((u'hiring',), 122)
# ((u'careerarc',), 91)
# ((u'day',), 52)
# ((u'today',), 51)
# ((u'time',), 50)
# ((u'people',), 46)
# ((u'life',), 42)
# ((u'thing',), 41)
# ((u'fit',), 32)
# ((u'year',), 31)
# ((u'love',), 31)
# ((u'opening',), 28)
# ((u'work',), 28)
# ((u'hiring', u'job'), 112)
# ((u'careerarc', u'hiring'), 91)
# ((u'careerarc', u'job'), 90)
# ((u'fit', u'job'), 29)
# ((u'job', u'opening'), 27)
# ((u'fit', u'hiring'), 25)
# ((u'hiring', u'opening'), 25)
# ((u'careerarc', u'fit'), 24)
# ((u'hiring', u'jobs'), 19)
# ((u'job', u'jobs'), 19)
# ((u'job', u'work'), 18)
# ((u'careerarc', u'jobs'), 18)
# ((u'job', u'retail'), 16)
# ((u'careerarc', u'opening'), 15)
# ((u'hiring', u'retail'), 15)
# ------ 28/11::04.00 -----
# (('',), 153)
# ((u'job',), 70)
# ((u'hiring',), 62)
# ((u'careerarc',), 39)
# ((u'day',), 33)
# ((u'people',), 32)
# ((u'time',), 30)
# ((u'today',), 25)
# ((u'guy',), 25)
# ((u'thing',), 22)
# ((u'life',), 20)
# ((u'word',), 18)
# ((u'amp',), 18)
# ((u'team',), 18)
# ((u'opening',), 17)
# ((u'hiring', u'job'), 55)
# ((u'careerarc', u'job'), 39)
# ((u'careerarc', u'hiring'), 39)
# ((u'hiring', u'opening'), 17)
# ((u'job', u'opening'), 17)
# ((u'job', u'jobs'), 13)
# ((u'hiring', u'jobs'), 13)
# ((u'job', u'retail'), 13)
# ((u'hiring', u'retail'), 11)
# ((u'careerarc', u'retail'), 11)
# ((u'job', u'store'), 10)
# ((u'careerarc', u'jobs'), 9)
# ((u'fit', u'job'), 9)
# ((u'hiring', u'team'), 8)
# ((u'hiring', u'store'), 7)
