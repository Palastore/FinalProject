# %%
import csv
with open('data.csv', 'rb') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
    for row in spamreader:
#         print row
        data = '#'.join(row)
#         print '#'.join(row)
        data = data.split('#')
        data[0] = "'" + data[0] +"'"
        data[1] = "'" + data[1] +"'"

        print '['+data[0]+','+data[2]+','+data[3]+'],'
# Out:
# ['Global',0,0],
# ['Bangkok and Suburb cities',9146431,1569],
# ['Central',12994347,622],
# ['North',11670186,1526],
# ['Northeast',21877600,1004],
# ['South',9241521,6225],
# ['Bangkok',5605672,19483],
# ['Nonthaburi',1186486,6338],
# ['Pathum Thani',1087994,5351],
# ['Samut Prakan',1266279,4363],
# ['Phetchaburi',475160,2470],
# ['Kanchanaburi',807666,2819],
# ['Chanthaburi',528718,2122],
# ['Chachoengsao',698197,2168],
# ['Chon Buri',1440783,6368],
# ['Chai Nat',331349,4762],
# ['Trat',218919,2557],
# ['Nakhon Nayok',257922,3552],
# ['Nakhon Pathom',892753,5197],
# ['Prachuap Khiri Khan',524132,6200],
# ['Prachin Buri',481596,417],
# ['Phra Nakhon Si Ayutthaya',806648,872],
# ['Rayong',684402,7195],
# ['Ratchaburi',844329,3577],
# ['Lop Buri',757686,823],
# ['Samut Songkhram',193039,5358],
# ['Samut Sakhon',523565,968],
# ['Sa Kaeo',554064,20107],
# ['Saraburi',631655,11678],
# ['Sing Buri',211175,12668],
# ['Suphan Buri',847748,6539],
# ['Ang Thong',282841,12681],
# ['Chiang Mai',1599679,8608],
# ['Chiang Rai',1160057,16407],
# ['Phetchabun',994960,9598],
# ['Phrae',451832,11472],
# ['Mae Hong Son',230419,6335],
# ['Kamphaeng Phet',729070,4531],
# ['Tak',523544,10816],
# ['Nakhon Sawan',1070178,12534],
# ['Nan',477741,4506],
# ['Phayao',480694,6596],
# ['Phichit',545428,7839],
# ['Phitsanulok',862130,6730],
# ['Lampang',749729,11425],
# ['Lamphun',404398,6947],
# ['Sukhothai',601121,10886],
# ['Uttaradit',458763,12778],
# ['Uthai Thani',330443,5513],
# ['Loei',634838,20494],
# ['Kalasin',984594,4305],
# ['Khon Kaen',1795386,10323],
# ['Chaiyaphum',1137428,5292],
# ['Nakhon Phanom',713751,4340],
# ['Nakhon Ratchasima',2625500,4162],
# ['Bueng Kan',420089,8299],
# ['Buri Ram',1583148,8840],
# ['Maha Sarakham',964126,9606],
# ['Mukdahan',346542,8124],
# ['Yasothon',539931,3027],
# ['Roi Et',1307335,3859],
# ['Si Sa Ket',1467779,3161],
# ['Sakon Nakhon',1141936,11730],
# ['Surin',1394032,15745],
# ['Nong Khai',515488,4709],
# ['Nong Bua Lam Phu',509701,6009],
# ['Amnat Charoen',375620,4918],
# ['Udon Thani',1570407,9943],
# ['Ubon Ratchathani',1849969,4475],
# ['Krabi',460724,1940],
# ['Chumphon',502178,4171],
# ['Trang',639696,3425],
# ['Nakhon Si Thammarat',1550298,543],
# ['Narathiwat',781839,4521],
# ['Pattani',692643,3298],
# ['Phangnga',261165,7394],
# ['Phatthalung',522421,2479],
# ['Phuket',378342,12892],
# ['Yala',516785,0],
# ['Ranong',174349,0],
# ['Songkhla',1403012,0],
# ['Satun',315524,0],
# ['Surat Thani',1042545,0],
